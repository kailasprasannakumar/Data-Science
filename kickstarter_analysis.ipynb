# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings
from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier 
from sklearn.metrics import r2_score, mean_squared_error,accuracy_score, balanced_accuracy_score, average_precision_score,f1_score
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier ,AdaBoostClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import preprocessing
import nltk
from sklearn.feature_extraction.text import TfidfTransformer
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
import string
from datetime import date
warnings.filterwarnings('ignore')

# %%
# Reading the data file
df = pd.read_csv('ks-projects-201801.csv')

# %%
# Checking the head of the data
df.head(7)
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
# 5  1000014025                               Monarch Espresso Bar
# 6  1000023410  Support Solar Roasted Coffee & Green Energy!  ...
#
#          category main_category currency    deadline     goal  \
# 0          Poetry    Publishing      GBP  2015-10-09   1000.0
# 1  Narrative Film  Film & Video      USD  2017-11-01  30000.0
# 2  Narrative Film  Film & Video      USD  2013-02-26  45000.0
# 3           Music         Music      USD  2012-04-16   5000.0
# 4    Film & Video  Film & Video      USD  2015-08-29  19500.0
# 5     Restaurants          Food      USD  2016-04-01  50000.0
# 6            Food          Food      USD  2014-12-21   1000.0
#
#               launched  pledged       state  backers country  usd pledged  \
# 0  2015-08-11 12:12:28      0.0      failed        0      GB          0.0
# 1  2017-09-02 04:43:57   2421.0      failed       15      US        100.0
# 2  2013-01-12 00:20:50    220.0      failed        3      US        220.0
# 3  2012-03-17 03:24:11      1.0      failed        1      US          1.0
# 4  2015-07-04 08:35:03   1283.0    canceled       14      US       1283.0
# 5  2016-02-26 13:38:27  52375.0  successful      224      US      52375.0
# 6  2014-12-01 18:30:44   1205.0  successful       16      US       1205.0
#
#    usd_pledged_real  usd_goal_real
# 0               0.0        1533.95
# 1            2421.0       30000.00
# 2             220.0       45000.00
# 3               1.0        5000.00
# 4            1283.0       19500.00
# 5           52375.0       50000.00
# 6            1205.0        1000.00

# %%
# Variable Information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378661 entries, 0 to 378660
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   ID                378661 non-null  int64
#  1   name              378657 non-null  object
#  2   category          378661 non-null  object
#  3   main_category     378661 non-null  object
#  4   currency          378661 non-null  object
#  5   deadline          378661 non-null  object
#  6   goal              378661 non-null  float64
#  7   launched          378661 non-null  object
#  8   pledged           378661 non-null  float64
#  9   state             378661 non-null  object
#  10  backers           378661 non-null  int64
#  11  country           378661 non-null  object
#  12  usd pledged       374864 non-null  float64
#  13  usd_pledged_real  378661 non-null  float64
#  14  usd_goal_real     378661 non-null  float64
# dtypes: float64(5), int64(2), object(8)
# memory usage: 43.3+ MB

# %%
# Getting dimensions of dataset

df.shape
# Out:
# (378661, 15)

# %%
# Taking column names to use them later

categories = df.main_category.unique()
categories
# Out:
# array(['Publishing', 'Film & Video', 'Music', 'Food', 'Design', 'Crafts',
#        'Games', 'Comics', 'Fashion', 'Theater', 'Art', 'Photography',
#        'Technology', 'Dance', 'Journalism'], dtype=object)

# %%
# Getting column value types

df.dtypes
# Out:
# ID                    int64
# name                 object
# category             object
# main_category        object
# currency             object
# deadline             object
# goal                float64
# launched             object
# pledged             float64
# state                object
# backers               int64
# country              object
# usd pledged         float64
# usd_pledged_real    float64
# usd_goal_real       float64
# dtype: object

# %%
# Getting short summary statistics of columns

df.describe().round(2)
# Out:
#                  ID          goal      pledged    backers  usd pledged  \
# count  3.786610e+05  3.786610e+05    378661.00  378661.00    374864.00
# mean   1.074731e+09  4.908079e+04      9682.98     105.62      7036.73
# std    6.190862e+08  1.183391e+06     95636.01     907.19     78639.75
# min    5.971000e+03  1.000000e-02         0.00       0.00         0.00
# 25%    5.382635e+08  2.000000e+03        30.00       2.00        16.98
# 50%    1.075276e+09  5.200000e+03       620.00      12.00       394.72
# 75%    1.610149e+09  1.600000e+04      4076.00      56.00      3034.09
# max    2.147476e+09  1.000000e+08  20338986.27  219382.00  20338986.27
#
#        usd_pledged_real  usd_goal_real
# count         378661.00   3.786610e+05
# mean            9058.92   4.545440e+04
# std            90973.34   1.152950e+06
# min                0.00   1.000000e-02
# 25%               31.00   2.000000e+03
# 50%              624.33   5.500000e+03
# 75%             4050.00   1.550000e+04
# max         20338986.27   1.663614e+08

# %%
# Checking for Null values

for each in df.columns:
    print(f'{each}: ',any(df[f'{each}'].isnull()))
# Out:
# ID:  False
# name:  True
# category:  False
# main_category:  False
# currency:  False
# deadline:  False
# goal:  False
# launched:  False
# pledged:  False
# state:  False
# backers:  False
# country:  False
# usd pledged:  True
# usd_pledged_real:  False
# usd_goal_real:  False

# %%
# Null values in a column 'name'

df[df['name'].isnull()]
# Out:
#                 ID name        category main_category currency    deadline  \
# 166851  1848699072  NaN  Narrative Film  Film & Video      USD  2012-02-29
# 307234   634871725  NaN     Video Games         Games      GBP  2013-01-06
# 309991   648853978  NaN  Product Design        Design      USD  2016-07-18
# 338931   796533179  NaN        Painting           Art      USD  2011-12-05
#
#             goal             launched  pledged      state  backers country  \
# 166851  200000.0  2012-01-01 12:35:31    100.0     failed        1      US
# 307234    2000.0  2012-12-19 23:57:48    196.0     failed       12      GB
# 309991    2500.0  2016-06-18 05:01:47      0.0  suspended        0      US
# 338931   35000.0  2011-11-06 23:55:55    220.0     failed        5      US
#
#         usd pledged  usd_pledged_real  usd_goal_real
# 166851       100.00            100.00      200000.00
# 307234       317.73            316.05        3224.97
# 309991         0.00              0.00        2500.00
# 338931       220.00            220.00       35000.00

# %%
# Null values in a column 'usd pledged'

df[df['usd pledged'].isnull()]
# Out:
#                 ID                                               name  \
# 169     1000694855                      STREETFIGHTERZ WHEELIE MURICA
# 328      100149523                        Duncan Woods - Chameleon EP
# 632     1003023003          The Making of Ashley Kelley's Debut Album
# 647     1003130892                       Butter Side Down Debut Album
# 749     1003629045                            Chase Goehring debut EP
# ...            ...                                                ...
# 378233   997971307  EQUUS International Film Festival®, all-equine...
# 378303   998319149                            Emily 2050 - Short Film
# 378434     9988744                             Matthew Stephens Music
# 378585   999610349     Lady Vendredi: Afrofuturist concept 12 inch EP
# 378588   999621278                     Jeune auteur a besoin de vous!
#
#             category main_category currency    deadline    goal  \
# 169     Film & Video  Film & Video      USD  2014-09-20  6500.0
# 328            Music         Music      AUD  2015-08-25  4500.0
# 632            Music         Music      USD  2015-04-09  3500.0
# 647            Music         Music      USD  2015-11-26  6000.0
# 749            Music         Music      USD  2016-03-21  3000.0
# ...              ...           ...      ...         ...     ...
# 378233  Film & Video  Film & Video      USD  2015-02-03  7500.0
# 378303  Film & Video  Film & Video      CAD  2014-05-23  3000.0
# 378434         Music         Music      USD  2016-02-05  5000.0
# 378585         Music         Music      GBP  2015-10-19  2000.0
# 378588    Publishing    Publishing      EUR  2015-11-20  1600.0
#
#                    launched  pledged      state  backers country  usd pledged  \
# 169     2014-08-06 21:28:36   555.00  undefined        0    N,0"          NaN
# 328     2015-08-04 12:05:17  4767.00  undefined        0    N,0"          NaN
# 632     2015-03-10 20:06:13  3576.00  undefined        0    N,0"          NaN
# 647     2015-11-02 22:09:19  7007.80  undefined        0    N,0"          NaN
# 749     2016-02-23 03:09:49  3660.38  undefined        0    N,0"          NaN
# ...                     ...      ...        ...      ...     ...          ...
# 378233  2014-12-05 04:19:14    10.00  undefined        0    N,0"          NaN
# 378303  2014-04-08 00:30:09  3102.00  undefined        0    N,0"          NaN
# 378434  2016-01-06 21:59:23   235.00  undefined        0    N,0"          NaN
# 378585  2015-09-21 22:33:18  2125.00  undefined        0    N,0"          NaN
# 378588  2015-10-21 21:28:13     0.00  undefined        0    N,0"          NaN
#
#         usd_pledged_real  usd_goal_real
# 169               555.00        6500.00
# 328              3402.08        3211.53
# 632              3576.00        3500.00
# 647              7007.80        6000.00
# 749              3660.38        3000.00
# ...                  ...            ...
# 378233             10.00        7500.00
# 378303           2845.61        2752.04
# 378434            235.00        5000.00
# 378585           3273.36        3080.81
# 378588              0.00        1710.08
#
# [3797 rows x 15 columns]

# %%
# highest backed product
high = df.loc[df['usd_pledged_real'].idxmax()]
high
# Out:
# ID                                                        1799979574
# name                Pebble Time - Awesome Smartwatch, No Compromises
# category                                              Product Design
# main_category                                                 Design
# currency                                                         USD
# deadline                                                  2015-03-28
# goal                                                        500000.0
# launched                                         2015-02-24 15:44:42
# pledged                                                  20338986.27
# state                                                     successful
# backers                                                        78471
# country                                                           US
# usd pledged                                              20338986.27
# usd_pledged_real                                         20338986.27
# usd_goal_real                                               500000.0
# Name: 157270, dtype: object

# %%
# least supported product
df7 =df
df7 = df7[(df7.goal > 1)].sort_values('usd_pledged_real')
low = df7.loc[df7['usd_pledged_real'].idxmin()]
low
# Out:
# ID                                       1000002330
# name                The Songs of Adelaide & Abullah
# category                                     Poetry
# main_category                            Publishing
# currency                                        GBP
# deadline                                 2015-10-09
# goal                                         1000.0
# launched                        2015-08-11 12:12:28
# pledged                                         0.0
# state                                        failed
# backers                                           0
# country                                          GB
# usd pledged                                     0.0
# usd_pledged_real                                0.0
# usd_goal_real                               1533.95
# Name: 0, dtype: object

# %%
# finding the outliers 
new_df = pd.DataFrame()
df8 = df[['usd_pledged_real', 'usd_goal_real']]
for i,j in enumerate(df8.columns):
    Q1 = np.percentile( df8[j], 25)
    Q3 = np.percentile( df8[j], 75)

    # 2.
    Q1,Q3 = np.percentile(df8[j] , [25,75])

    # Find IQR, upper limit, lower limit
    IQR = Q3 - Q1
    ul = Q3+1.5*IQR
    ll = Q1-1.5*IQR

    # Find outliers
    outliers = df8[j][(df8[j] > ul) | (df8[j] < ll)]
    new_df = new_df.append(outliers, ignore_index=True)
   
    

new_df = new_df.T 
new_df.columns = df8.columns

# %%
new_df.describe()
# Out:
#        usd_pledged_real  usd_goal_real
# count      5.057800e+04   4.550800e+04
# mean       5.825341e+04   3.221480e+05
# std        2.431794e+05   3.312619e+06
# min        1.007900e+04   3.575379e+04
# 25%        1.363981e+04   5.000000e+04
# 50%        2.109700e+04   6.950000e+04
# 75%        4.121500e+04   1.200000e+05
# max        2.033899e+07   1.663614e+08

# %%
# Plotting the box plots to check outliers
sns.boxplot(df['usd_goal_real'])
# Out:
# <AxesSubplot:xlabel='usd_goal_real'>

# %%
# plotting bix plot
sns.boxplot(df['usd_pledged_real'])
# Out:
# <AxesSubplot:xlabel='usd_pledged_real'>

# %% [markdown]
# # Pie chart showing projects by their condition

# %%
variable = 'state'

pie_chart = df[variable].value_counts()
output = pd.DataFrame((df[variable].value_counts()))

# %%
temp_pie = pie_chart[:4]
temp_pie[3] = pie_chart[3:6].sum()
temp_pie = temp_pie.rename(index= {'undefined' : 'others'})
temp_pie.name = ''

# %%
output['Share'] = (output / output.sum()*100).round(2)
output['Share'] = output['Share'].map("{:,.2f}%".format)
output.index.rename('state', inplace=True)
output = output.rename(columns = {'state': 'Number'})

# %%
#pie_chart.plot(kind = "pie", startangle=90, autopct='%1.0f%%', pctdistance=1.1, labeldistance=1.2)
temp_pie.plot(kind = "pie", startangle=90, autopct='%1.0f%%', pctdistance=1.1, labeldistance=1.2)
plt.title('Proportion of project condition')
output
# Out:
#             Number   Share
# state
# failed      197719  52.22%
# successful  133956  35.38%
# canceled     38779  10.24%
# undefined     3562   0.94%
# live          2799   0.74%
# suspended     1846   0.49%

# %% [markdown]
# # Bar graph showing projects by their main category

# %%
variable = "main_category"

pie_chart = df[variable].value_counts()
output = pd.DataFrame((df[variable].value_counts()))

# %%
output
output['Share'] = (output / output.sum()*100).round(2)
output['Share'] = output['Share'].map("{:,.2f}%".format)
output.index.rename('Main Category', inplace=True)
output = output.rename(columns = {'main_category': 'Number'})

# %%
pie_chart.plot(kind = "bar")
plt.title('Number of projects by their category')
output
# Out:
#                Number   Share
# Main Category
# Film & Video    63585  16.79%
# Music           51918  13.71%
# Publishing      39874  10.53%
# Games           35231   9.30%
# Technology      32569   8.60%
# Design          30070   7.94%
# Art             28153   7.43%
# Food            24602   6.50%
# Fashion         22816   6.03%
# Theater         10913   2.88%
# Comics          10819   2.86%
# Photography     10779   2.85%
# Crafts           8809   2.33%
# Journalism       4755   1.26%
# Dance            3768   1.00%

# %% [markdown]
# # Bar graph showing projects by required currency types

# %%
variable = 'currency'

pie_chart = df[variable].value_counts()
output = pd.DataFrame((df[variable].value_counts()))

# %%
output['Share'] = (output / output.sum()*100).round(2)
output['Share'] = output['Share'].map("{:,.2f}%".format)
output.index.rename('Currency types', inplace=True)
output = output.rename(columns = {'currency': 'Number of project'})

# %%
pie_chart.plot(kind = "barh")
plt.title('Number of projects by their required currency types')

output
# Out:
#                 Number of project   Share
# Currency types
# USD                        295365  78.00%
# GBP                         34132   9.01%
# EUR                         17405   4.60%
# CAD                         14962   3.95%
# AUD                          7950   2.10%
# SEK                          1788   0.47%
# MXN                          1752   0.46%
# NZD                          1475   0.39%
# DKK                          1129   0.30%
# CHF                           768   0.20%
# NOK                           722   0.19%
# HKD                           618   0.16%
# SGD                           555   0.15%
# JPY                            40   0.01%

# %% [markdown]
# # Pie chart showing projects by their countries

# %%
temp_df = df[df['country'] != 'N,0"']

variable = 'country'
output = pd.DataFrame((temp_df[variable].value_counts()))

# %%
output['Share'] = (output / output.sum()*100).round(2)
output.index.rename('Countries', inplace=True)
output = output.rename(columns = {'country': 'Number of project'})

# %%
temp = output.copy(deep=True)
temp_output = temp[:6]
temp_output.iloc[5] = temp[5:].sum()
temp_output = temp_output.rename(index= {'FR' : 'Others'})

temp_output
# Out:
#            Number of project  Share
# Countries
# US                    292627  78.06
# GB                     33672   8.98
# CA                     14756   3.94
# AU                      7839   2.09
# DE                      4171   1.11
# Others                 21799   5.83

# %%
output['Share'] = output['Share'].map("{:,.2f}%".format)

# %%
#temp_output['Share'] = temp_output['Share'].map("{:,.2f}%".format)
temp_output.Share.name = ''
temp_output
# Out:
#            Number of project  Share
# Countries
# US                    292627  78.06
# GB                     33672   8.98
# CA                     14756   3.94
# AU                      7839   2.09
# DE                      4171   1.11
# Others                 21799   5.83

# %%
temp_output.Share.plot(kind = "pie",  autopct='%1.0f%%', pctdistance=1.1, labeldistance=1.2)
plt.title('Number of projects by their countries')

output
# Out:
#            Number of project   Share
# Countries
# US                    292627  78.06%
# GB                     33672   8.98%
# CA                     14756   3.94%
# AU                      7839   2.09%
# DE                      4171   1.11%
# FR                      2939   0.78%
# IT                      2878   0.77%
# NL                      2868   0.77%
# ES                      2276   0.61%
# SE                      1757   0.47%
# MX                      1752   0.47%
# NZ                      1447   0.39%
# DK                      1113   0.30%
# IE                       811   0.22%
# CH                       761   0.20%
# NO                       708   0.19%
# HK                       618   0.16%
# BE                       617   0.16%
# AT                       597   0.16%
# SG                       555   0.15%
# LU                        62   0.02%
# JP                        40   0.01%

# %% [markdown]
# # Success rate of projects by countries

# %%
# Dropping unknown values in a column 'country'
total_df = df[df['country'] != 'N,0"']
total_df.shape
# Out:
# (374864, 15)

# %%
#total_df.groupby(['main_category', 'country'])['state'].aggregate('count').unstack()

# %%
# Groupping number of all projects by their categories and countries

tdf = total_df.pivot_table('state', index='country', columns = 'main_category', aggfunc='count', margins =True)
tdf
# Out:
# main_category      Art   Comics  Crafts   Dance   Design  Fashion  \
# country
# AT                40.0      6.0    13.0     3.0     82.0     37.0
# AU               425.0    188.0   183.0    32.0    929.0    717.0
# BE                45.0      9.0    21.0     1.0     71.0     54.0
# CA              1067.0    521.0   426.0    94.0   1500.0   1060.0
# CH                48.0      6.0    22.0     4.0    132.0     65.0
# DE               221.0     47.0    95.0    20.0    563.0    287.0
# DK                89.0     15.0    33.0     3.0    175.0     77.0
# ES               163.0     36.0    42.0     7.0    218.0    193.0
# FR               175.0     33.0    77.0    18.0    304.0    254.0
# GB              2667.0    867.0   904.0   280.0   2706.0   2372.0
# HK                34.0      8.0    12.0     1.0    236.0     45.0
# IE                61.0      9.0    35.0     5.0     80.0     36.0
# IT               183.0     46.0    48.0     8.0    382.0    295.0
# JP                 2.0      NaN     NaN     NaN      8.0      8.0
# LU                 4.0      1.0     NaN     NaN      6.0      4.0
# MX               160.0     35.0    63.0    24.0    108.0     76.0
# NL               191.0     17.0    60.0    16.0    346.0    274.0
# NO                34.0     17.0    17.0     7.0     62.0     41.0
# NZ                91.0     16.0    43.0     8.0    157.0    101.0
# SE               112.0     25.0    37.0     7.0    172.0    128.0
# SG                30.0      7.0    30.0     1.0    140.0    104.0
# US             22311.0   8910.0  6648.0  3228.0  21690.0  16584.0
# All            28153.0  10819.0  8809.0  3767.0  30067.0  22812.0
#
# main_category  Film & Video     Food    Games  Journalism    Music  \
# country
# AT                     51.0     42.0     69.0        11.0     37.0
# AU                    940.0    477.0    961.0       109.0    470.0
# BE                     47.0     37.0     98.0         9.0     55.0
# CA                   1703.0   1047.0   1884.0       218.0   1172.0
# CH                     55.0     50.0     65.0         5.0     49.0
# DE                    314.0    227.0    665.0        71.0    297.0
# DK                    112.0     60.0    105.0        22.0    102.0
# ES                    169.0    115.0    507.0        41.0    142.0
# FR                    274.0    136.0    502.0        35.0    183.0
# GB                   5782.0   1649.0   4012.0       451.0   2772.0
# HK                     10.0     10.0     76.0         1.0      6.0
# IE                     91.0     59.0     78.0        15.0     68.0
# IT                    211.0    186.0    392.0        54.0    164.0
# JP                      1.0      NaN     10.0         NaN      1.0
# LU                      3.0      5.0      4.0         1.0      6.0
# MX                    317.0    102.0    148.0        33.0    207.0
# NL                    213.0    182.0    412.0        42.0    196.0
# NO                     75.0     48.0     85.0        20.0     82.0
# NZ                    189.0    100.0    183.0        21.0     95.0
# SE                    202.0    103.0    275.0        54.0    178.0
# SG                     16.0     23.0     59.0         1.0     10.0
# US                  51922.0  19941.0  24636.0      3540.0  43238.0
# All                 62697.0  24599.0  35226.0      4754.0  49530.0
#
# main_category  Photography  Publishing  Technology  Theater     All
# HK                  61.78      NaN  65.05
# IE                  82.93    47.62  74.48
# IT                  91.35    81.82  84.75
# JP                  71.43      NaN  82.50
# LU                  90.00     0.00  69.35
# MX                  92.92    60.29  77.40
# NL                  83.03    71.43  78.49
# NO                  91.45    63.64  77.12
# NZ                  83.25    52.63  69.04
# SE                  87.78    62.50  71.03
# SG                  80.25    50.00  67.93
# US                  78.09    40.05  62.65
# All                 80.24    40.12  64.29

# %%
# Plotting Success rate of each category across countries

for i in range(success_rate.shape[1]-1):
    plt.subplot(8,2, i+1)
    success_rate.iloc[:len(success_rate)-1, i].plot(kind = "bar")
    plt.title(f'Success rate of {success_rate.columns[i]} by countries')    
    
        
plt.subplots_adjust(left=0.1,
                    bottom=-0.5,
                    right=2.0,
                    top=4.0,
                    wspace=0.4,
                    hspace=0.4)

plt.show()

# %%
# Plotting Success rate of categories in a specific country

sucess_rate0 = success_rate.T


for i in range(sucess_rate0.shape[1]-1):
    plt.subplot(12,2, i+1)
    sucess_rate0.iloc[:, i].plot(kind = "bar")
    plt.title(f'\nSuccess rate of categories in a country {sucess_rate0.columns[i]}\n')
    plt.ylabel('Success rate')
    plt.xlabel('')
        
plt.subplots_adjust(left=0.1,
                    bottom=-15.0,
                    right=2.0,
                    top=4.0,
                    wspace=0.4,
                    hspace=0.4)

plt.show()

# %% [markdown]
# # Mean required amount of successful projects in each category

# %%
success_df
# Out:
#                 ID                                               name  \
# 5       1000014025                               Monarch Espresso Bar
# 6       1000023410  Support Solar Roasted Coffee & Green Energy!  ...
# 11       100005484                                   Lisa Lim New CD!
# 14      1000057089  Tombstone: Old West tabletop game and miniatur...
# 18      1000070642                Mike Corey's Darkness & Light Album
# ...            ...                                                ...
# 378642   999929142  ÉPOUVANTAILS : 28mm Figurines de jeux pour KIN...
# 378644   999934908                               The Manual Bar Blade
# 378646   999943841                                The Dog Coffee Book
# 378651   999969812                                       AT THE BEACH
# 378652   999971898                        Beach Wrestling Documentary
#
#                 category main_category currency    deadline     goal  \
# 5            Restaurants          Food      USD  2016-04-01  50000.0
# 6                   Food          Food      USD  2014-12-21   1000.0
# 11            Indie Rock         Music      USD  2013-04-08  12500.0
# 14        Tabletop Games         Games      GBP  2017-05-03   5000.0
# 18                 Music         Music      USD  2012-08-17    250.0
# ...                  ...           ...      ...         ...      ...
# 378642    Tabletop Games         Games      EUR  2017-10-31   1000.0
# 378644    Product Design        Design      USD  2015-12-15   3500.0
# 378646  Children's Books    Publishing      USD  2013-11-30    950.0
# 378651   Classical Music         Music      CAD  2014-03-22   5000.0
# 378652       Documentary  Film & Video      NOK  2015-04-28  20000.0
#
#                    launched   pledged       state  backers country  \
# 5       2016-02-26 13:38:27  52375.00  successful      224      US
# 6       2014-12-01 18:30:44   1205.00  successful       16      US
# 11      2013-03-09 06:42:58  12700.00  successful      100      US
# 14      2017-04-05 19:44:18  94175.00  successful      761      GB
# 18      2012-08-02 14:11:32    250.00  successful        7      US
# ...                     ...       ...         ...      ...     ...
# 378642  2017-10-04 11:26:44   1246.00  successful       35      FR
# 378644  2015-11-23 07:33:14   6169.00  successful      120      US
# 378646  2013-10-18 21:35:04   1732.02  successful       31      US
# 378651  2014-02-20 01:00:16   5501.00  successful       78      CA
# 378652  2015-03-29 21:30:33  21500.00  successful       36      NO
#
#         usd pledged  usd_pledged_real  usd_goal_real
# 5          52375.00          52375.00       50000.00
# 6           1205.00           1205.00        1000.00
# 11         12700.00          12700.00       12500.00
# 14         57763.78         121857.33        6469.73
# 18           250.00            250.00         250.00
# ...             ...               ...            ...
# 378642        66.72           1452.47        1165.70
# 378644      6169.00           6169.00        3500.00
# 378646      1732.02           1732.02         950.00
# 378651      5019.92           4983.69        4529.81
# 378652      2698.97           2875.83        2675.19
#
# [133851 rows x 15 columns]

# %%
df5 = df[(df['state'] == "successful")] 
df5.describe()
# Out:
#                  ID          goal       pledged        backers   usd pledged  \
# count  1.339560e+05  1.339560e+05  1.339560e+05  133956.000000  1.338510e+05
# mean   1.073727e+09  1.016296e+04  2.409978e+04     263.921362  1.735603e+04
# std    6.191514e+08  3.124829e+04  1.584713e+05    1504.580142  1.301228e+05
# min    2.110900e+04  1.000000e-02  1.000000e+00       0.000000  0.000000e+00
# 25%    5.354443e+08  1.250000e+03  1.977750e+03      33.000000  1.162000e+03
# 50%    1.076595e+09  3.923000e+03  5.117000e+03      71.000000  3.655660e+03
# 75%    1.608161e+09  1.000000e+04  1.344025e+04     167.000000  1.042600e+04
# max    2.147476e+09  2.000000e+06  2.033899e+07  219382.000000  2.033899e+07
#
#        usd_pledged_real  usd_goal_real
# count      1.339560e+05   1.339560e+05
# mean       2.267080e+04   9.532853e+03
# std        1.510903e+05   2.796144e+04
# min        7.900000e-01   1.000000e-02
# 25%        2.000000e+03   1.301915e+03
# 50%        5.107250e+03   3.837740e+03
# 75%        1.323208e+04   1.000000e+04
# max        2.033899e+07   2.015609e+06

# %%
df6 = df[(df['state'] == "failed")] 
df6.describe()
# Out:
#                  ID          goal       pledged        backers    usd pledged  \
# count  1.977190e+05  1.977190e+05  1.977190e+05  197719.000000  197614.000000
# mean   1.074639e+09  6.734685e+04  1.426971e+03      16.422352    1133.741030
# std    6.192215e+08  1.447227e+06  9.564415e+03      71.224123    6221.653617
# min    5.971000e+03  1.500000e-01  0.000000e+00       0.000000       0.000000
# 25%    5.385642e+08  2.500000e+03  3.000000e+00       1.000000       0.000000
# 50%    1.073242e+09  7.500000e+03  1.000000e+02       3.000000      66.000000
# 75%    1.611052e+09  2.000000e+04  6.710000e+02      12.000000     512.000000
# max    2.147467e+09  1.000000e+08  1.748630e+06    6550.000000  721036.460000
#
#        usd_pledged_real  usd_goal_real
# count     197719.000000   1.977190e+05
# mean        1320.603817   6.317474e+04
# std         6820.249351   1.435683e+06
# min            0.000000   1.500000e-01
# 25%            2.640000   2.500000e+03
# 50%          100.000000   7.500000e+03
# 75%          663.000000   2.000000e+04
# max       757352.940000   1.663614e+08

# %%
# average contribution by a backer
df6 = df
df6 = df6[df6.backers != 0]
df6['ave_cont'] = df6['usd_pledged_real']/df6['backers']
df6['ave_cont'].mean()
# Out:
# 75.69746482951851

# %%
df5 = df[(df['state'] == "successful")] 
df5.describe()
# Out:
#                  ID          goal       pledged        backers   usd pledged  \
# count  1.339560e+05  1.339560e+05  1.339560e+05  133956.000000  1.338510e+05
# mean   1.073727e+09  1.016296e+04  2.409978e+04     263.921362  1.735603e+04
# std    6.191514e+08  3.124829e+04  1.584713e+05    1504.580142  1.301228e+05
# min    2.110900e+04  1.000000e-02  1.000000e+00       0.000000  0.000000e+00
# 25%    5.354443e+08  1.250000e+03  1.977750e+03      33.000000  1.162000e+03
# 50%    1.076595e+09  3.923000e+03  5.117000e+03      71.000000  3.655660e+03
# 75%    1.608161e+09  1.000000e+04  1.344025e+04     167.000000  1.042600e+04
# max    2.147476e+09  2.000000e+06  2.033899e+07  219382.000000  2.033899e+07
#
#        usd_pledged_real  usd_goal_real
# count      1.339560e+05   1.339560e+05
# mean       2.267080e+04   9.532853e+03
# std        1.510903e+05   2.796144e+04
# min        7.900000e-01   1.000000e-02
# 25%        2.000000e+03   1.301915e+03
# 50%        5.107250e+03   3.837740e+03
# 75%        1.323208e+04   1.000000e+04
# max        2.033899e+07   2.015609e+06

# %%
df6 = df[(df['state'] == "failed")] 
df6.describe()
# Out:
#                  ID          goal       pledged        backers    usd pledged  \
# count  1.977190e+05  1.977190e+05  1.977190e+05  197719.000000  197614.000000
# mean   1.074639e+09  6.734685e+04  1.426971e+03      16.422352    1133.741030
# std    6.192215e+08  1.447227e+06  9.564415e+03      71.224123    6221.653617
# min    5.971000e+03  1.500000e-01  0.000000e+00       0.000000       0.000000
# 25%    5.385642e+08  2.500000e+03  3.000000e+00       1.000000       0.000000
# 50%    1.073242e+09  7.500000e+03  1.000000e+02       3.000000      66.000000
# 75%    1.611052e+09  2.000000e+04  6.710000e+02      12.000000     512.000000
# max    2.147467e+09  1.000000e+08  1.748630e+06    6550.000000  721036.460000
#
#        usd_pledged_real  usd_goal_real
# count     197719.000000   1.977190e+05
# mean        1320.603817   6.317474e+04
# std         6820.249351   1.435683e+06
# min            0.000000   1.500000e-01
# 25%            2.640000   2.500000e+03
# 50%          100.000000   7.500000e+03
# 75%          663.000000   2.000000e+04
# max       757352.940000   1.663614e+08

# %%
# average contribution by a backer
df6 = df
df6 = df6[df6.backers != 0]
df6['ave_cont'] = df6['usd_pledged_real']/df6['backers']
df6['ave_cont'].mean()
# Out:
# 75.69746482951851

# %%
# Checking the average mean funding for the projects
categories = df.main_category.unique()
categories
goals = []

for each in categories:
    temp = df.query('category == @each')['goal']
    temp = temp.tolist()
    goals.append(temp)
    
goals
goal_stat = pd.DataFrame()

for i in range(len(categories)):
    statistics = pd.Series(goals[i]).describe().round(2)
    goal_stat = pd.concat([goal_stat, statistics], axis = 1)

goal_stat.columns = categories
pd.options.display.float_format = '{:.2f}'.format
goal_stat
# Out:
#         Publishing  Film & Video       Music        Food      Design  \
# count      6018.00      10108.00    15727.00    11493.00     4199.00
# mean      47428.16      81400.97    21427.04    36882.02    41764.75
# std     1425110.85    1152043.70   478455.45   952936.99   713049.14
# min           1.00          1.00        1.00        1.00        1.00
# 25%        2000.00       2000.00     2000.00     3000.00     2500.00
# 50%        5000.00       6000.00     5000.00    10000.00     8500.00
# 75%       13000.00      22000.00    10000.00    20000.00    22000.00
# max   100000000.00  100000000.00 50000000.00 99000000.00 45000000.00
#
#           Crafts       Games       Comics    Fashion    Theater          Art  \
# count    4664.00     3226.00      4996.00    8554.00    7057.00      8253.00
# mean    10678.46    55731.22     33046.77   15380.34   12646.55     48928.06
# std     60341.96   613704.62   1428953.88   59180.29  125270.56   1508893.86
# min         1.00        1.00         1.00       1.00       1.00         1.00
# 25%       600.00     2000.00      1500.00    2000.00    1500.00      1000.00
# 50%      2180.00     6000.00      3845.00    5500.00    3000.00      3000.00
# 75%      6881.25    20000.00      8000.00   15000.00    7000.00      8000.00
# max   2500000.00 21474836.47 100000000.00 3350000.00 8000000.00 100000000.00
#
#        Photography   Technology      Dance  Journalism
# count      5752.00      6930.00    2322.00     1747.00
# mean      10714.26    182840.15    8031.34    61547.16
# std      134456.99   2717067.06   38704.44  1007540.32
# min           1.00         1.00       5.00        1.00
# 25%        1500.00      6500.00    1500.00     2000.00
# 50%        3590.00     20000.00    3000.00     5000.00
# 75%        8500.00     55000.00    6000.00    14283.94
# max    10000000.00 100000000.00 1000000.00 35000000.00

# %%
# Below graph shows the mean funding required for different categories
plt.figure(1,(15,8))
sns.barplot(y = 'mean', x = goal_stat.T.index , data = goal_stat.T)
plt.title('Average Funding Required for different categories of Successful Projects')
plt.ylabel('Funding')
plt.xlabel('Categories')
_ = plt.xticks(rotation= 45)

# %%
# Parsing the columns launched and deadline
df1 = df[['deadline','launched']]
for i in df1.columns:
    df1[i] =   pd.to_datetime(df1[i])
    df1[str(i) + '_date'] = df1[i].dt.date
    df[str(i)+ '_year'] = df1[i].dt.year
    df[str(i)+'_month'] = df1[i].dt.month
    df[str(i)+'_monthday'] = df1[i].dt.day
    df[str(i)+'_weekday'] = df1[i].dt.day_name()
    df[str(i)+ '_quarter'] = df1[i].dt.quarter

# %%
df['state'].value_counts()
# Out:
# failed        197719
# successful    133956
# canceled       38779
# undefined       3562
# live            2799
# suspended       1846
# Name: state, dtype: int64

# %%
sns.countplot(x = 'deadline_month', data = df)
# Out:
# <AxesSubplot:xlabel='deadline_month', ylabel='count'>

# %%
sns.countplot(x = 'launched_month', data = df)
# Out:
# <AxesSubplot:xlabel='launched_month', ylabel='count'>

# %%
# successfull projects launched and deadline month
fig = plt.figure(1, (14, 4))
df3 = df[df['state'] == 'successful']
ax = plt.subplot(1,2,1)
sns.countplot(x = 'launched_month', data = df3)
ax = plt.subplot(1,2,2)
sns.countplot(x = 'deadline_month', data = df3)
plt.title('Projects filtered by months')
plt.ylabel('Number of Projects')
plt.xlabel('Months')
# Out:
# Text(0.5, 0, 'Months')

# %%
# launched and deadline month for failed months. June and july seem to be having an high failure rate.
fig = plt.figure(1, (14, 4))
df3 = df[df['state'] == 'failed']
ax = plt.subplot(1,2,1)
sns.countplot(x = 'launched_month', data = df3)
ax = plt.subplot(1,2,2)
sns.countplot(x = 'deadline_month', data = df3)
# Out:
# <AxesSubplot:xlabel='deadline_month', ylabel='count'>

# %%
fig = plt.figure(1, (14, 4))
df3 = df[df['state'] == 'failed']
ax = plt.subplot(1,2,1)
sns.countplot(x = 'launched_weekday', data = df3)
ax = plt.subplot(1,2,2)
sns.countplot(x = 'deadline_weekday', data = df3)
# Out:
# <AxesSubplot:xlabel='deadline_weekday', ylabel='count'>

# %%
fig = plt.figure(1, (16, 4))
df3 = df[df['state'] == 'successful']
ax = plt.subplot(1,2,1)
sns.countplot(x = 'launched_weekday', data = df3)
plt.title('Successful Projects filtered on Launched Weekdays')
plt.ylabel('Number of Projects')
plt.xlabel('Weekday')
ax = plt.subplot(1,2,2)
sns.countplot(x = 'deadline_weekday', data = df3)
# Out:
# <AxesSubplot:xlabel='deadline_weekday', ylabel='count'>

# %%
# counting the number of weekdays between quarters.
df['weekday_count'] = df1.apply(lambda x: np.busday_count(x.launched_date, x.deadline_date), axis=1)

# %%
df.head(5)
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency    deadline     goal  \
# 0          Poetry    Publishing      GBP  2015-10-09  1000.00
# 1  Narrative Film  Film & Video      USD  2017-11-01 30000.00
# 2  Narrative Film  Film & Video      USD  2013-02-26 45000.00
# 3           Music         Music      USD  2012-04-16  5000.00
# 4    Film & Video  Film & Video      USD  2015-08-29 19500.00
#
#               launched  pledged     state  ...  deadline_month  \
# 0  2015-08-11 12:12:28     0.00    failed  ...              10
# 1  2017-09-02 04:43:57  2421.00    failed  ...              11
# 2  2013-01-12 00:20:50   220.00    failed  ...               2
# 3  2012-03-17 03:24:11     1.00    failed  ...               4
# 4  2015-07-04 08:35:03  1283.00  canceled  ...               8
#
#   deadline_monthday  deadline_weekday  deadline_quarter  launched_year  \
# 0                 9            Friday                 4           2015
# 1                 1         Wednesday                 4           2017
# 2                26           Tuesday                 1           2013
# 3                16            Monday                 2           2012
# 4                29          Saturday                 3           2015
#
#    launched_month  launched_monthday  launched_weekday launched_quarter  \
# 0               8                 11           Tuesday                3
# 1               9                  2          Saturday                3
# 2               1                 12          Saturday                1
# 3               3                 17          Saturday                1
# 4               7                  4          Saturday                3
#
#    weekday_count
# 0             43
# 1             42
# 2             31
# 3             20
# 4             40
#
# [5 rows x 26 columns]

# %%
sns.barplot(x ='state',y='weekday_count',hue='deadline_month', data = df,ci=None)
plt.legend(ncol=3)

# %%
len(df)
# Out:
# 378661

# %%
df.drop(df['weekday_count'].idxmax(),inplace=True)

# %%
df.loc[df['weekday_count'].idxmax()]
# Out:
# ID                                                       1014746686
# name                 Salt of the Earth: A Dead Sea Movie (Canceled)
# category                                               Film & Video
# main_category                                          Film & Video
# currency                                                        USD
# deadline                                                 2010-09-15
# goal                                                        5000.00
# launched                                        1970-01-01 01:00:00
# pledged                                                        0.00
# state                                                      canceled
# backers                                                           0
# country                                                          US
# usd pledged                                                    0.00
# usd_pledged_real                                               0.00
# usd_goal_real                                               5000.00
# deadline_year                                                  2010
# deadline_month                                                    9
# deadline_monthday                                                15
# deadline_weekday                                          Wednesday
# deadline_quarter                                                  3
# launched_year                                                  1970
# launched_month                                                    1
# launched_monthday                                                 1
# launched_weekday                                           Thursday
# launched_quarter                                                  1
# weekday_count                                                 10619
# Name: 2842, dtype: object

# %%
df['weekday_count'].nlargest(10)
# Out:
# 2842      10619
# 48147     10597
# 94579     10543
# 75397     10536
# 247913    10523
# 273779    10507
# 38476        66
# 61014        66
# 74196        66
# 85716        66
# Name: weekday_count, dtype: int64

# %%
df.nlargest(6,'weekday_count')
# Out:
#                 ID                                               name  \
# 2842    1014746686     Salt of the Earth: A Dead Sea Movie (Canceled)
# 48147   1245461087  1st Super-Size Painting - Social Network Owned...
# 94579   1480763647  Support Solo Theater! Help "Ungrateful Daughte...
# 75397   1384087152                                "ICHOR"  (Canceled)
# 247913   330942060  Help RIZ Make A Charity Album: 8 Songs, 8 Caus...
# 273779   462917959     Identity Communications Infographic (Canceled)
#
#             category main_category currency    deadline     goal  \
# 2842    Film & Video  Film & Video      USD  2010-09-15  5000.00
# 48147            Art           Art      USD  2010-08-14 15000.00
# 94579        Theater       Theater      USD  2010-06-01  4000.00
# 75397   Film & Video  Film & Video      USD  2010-05-21   700.00
# 247913         Music         Music      USD  2010-05-04 10000.00
# 273779        Design        Design      USD  2010-04-10   500.00
#
#                    launched  pledged     state  ...  deadline_month  \
# 2842    1970-01-01 01:00:00     0.00  canceled  ...               9
# 48147   1970-01-01 01:00:00     0.00  canceled  ...               8
# 94579   1970-01-01 01:00:00     0.00  canceled  ...               6
# 75397   1970-01-01 01:00:00     0.00  canceled  ...               5
# 247913  1970-01-01 01:00:00     0.00  canceled  ...               5
# 273779  1970-01-01 01:00:00     0.00  canceled  ...               4
#
#        deadline_monthday  deadline_weekday  deadline_quarter  launched_year  \
# 2842                  15         Wednesday                 3           1970
# 48147                 14          Saturday                 3           1970
# 94579                  1           Tuesday                 2           1970
# 75397                 21            Friday                 2           1970
# 247913                 4           Tuesday                 2           1970
# 273779                10          Saturday                 2           1970
#
#         launched_month  launched_monthday  launched_weekday launched_quarter  \
# 2842                 1                  1          Thursday                1
# 48147                1                  1          Thursday                1
# 94579                1                  1          Thursday                1
# 75397                1                  1          Thursday                1
# 247913               1                  1          Thursday                1
# 273779               1                  1          Thursday                1
#
#         weekday_count
# 2842            10619
# 48147           10597
# 94579           10543
# 75397           10536
# 247913          10523
# 273779          10507
#
# [6 rows x 26 columns]

# %%
df.drop(df['weekday_count'].nlargest(6).index,inplace=True)
#df['weekday_count'].idxmax(5)

# %%
sns.barplot(x ='state',y='weekday_count', data = df,ci=None)
plt.legend(ncol=3)
plt.title('Weekdays between Project launch and deadline and State of Project')
plt.ylabel('Weekday count')
plt.xlabel('State of the Project')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0.5, 0, 'State of the Project')

# %%
# Plotting successful projects by quarter 
fig = plt.figure(1, (14, 4))
df3 = df[df['state'] == 'successful']
ax = plt.subplot(1,2,1)
sns.countplot(x = 'launched_quarter', data = df3)
ax = plt.subplot(1,2,2)
sns.countplot(x = 'deadline_quarter', data = df3)
plt.title('Projects filtered by Quarters')
plt.ylabel('Number of Projects')
plt.xlabel('Quarters')
# Out:
# Text(0.5, 0, 'Quarters')

# %%
fig = plt.figure(1, (14, 4))
df3 = df[df['state'] == 'failed']
ax = plt.subplot(1,2,1)
sns.countplot(x = 'launched_quarter', data = df3)
ax = plt.subplot(1,2,2)
sns.countplot(x = 'deadline_quarter', data = df3)
# Out:
# <AxesSubplot:xlabel='deadline_quarter', ylabel='count'>

# %%
sns.countplot(x = 'deadline_quarter', data = df) # normally lesser projects are anouncced in the first quarter
# Out:
# <AxesSubplot:xlabel='deadline_quarter', ylabel='count'>

# %%
# Plotting project counts over the years
df9 = df[(df['state'] == "failed") | (df['state'] == "successful")] 
df1 = df[['deadline','launched']]
for i in df1.columns:
    df1[i] =   pd.to_datetime(df1[i])
    df9[str(i) + '_date'] = df1[i].dt.date
    df9[str(i)+ '_year'] = df1[i].dt.year
df9 = df9.groupby('launched_year').count()

# %%
sns.lineplot(y = df9['ID'], x = df9.index)
plt.title('Projects over the years')
plt.ylabel('Number of Projects')
plt.xlabel('Years')
df9
# Out:
#                   ID   name  category  main_category  currency  deadline  \
# launched_year
# 2009            1179   1179      1179           1179      1179      1179
# 2010            9577   9577      9577           9577      9577      9577
# 2011           24049  24048     24049          24049     24049     24049
# 2012           38480  38478     38480          38480     38480     38480
# 2013           41101  41101     41101          41101     41101     41101
# 2014           59306  59306     59306          59306     59306     59306
# 2015           65272  65272     65272          65272     65272     65272
# 2016           49292  49292     49292          49292     49292     49292
# 2017           43419  43419     43419          43419     43419     43419
#
#                 goal  launched  pledged  state  ...  deadline_monthday  \
# launched_year                                   ...
# 2009            1179      1179     1179   1179  ...               1179
# 2010            9577      9577     9577   9577  ...               9577
# 2011           24049     24049    24049  24049  ...              24049
# 2012           38480     38480    38480  38480  ...              38480
# 2013           41101     41101    41101  41101  ...              41101
# 2014           59306     59306    59306  59306  ...              59306
# 2015           65272     65272    65272  65272  ...              65272
# 2016           49292     49292    49292  49292  ...              49292
# 2017           43419     43419    43419  43419  ...              43419
#
#                deadline_weekday  deadline_quarter  launched_month  \
# launched_year
# 2009                       1179              1179            1179
# 2010                       9577              9577            9577
# 2011                      24049             24049           24049
# 2012                      38480             38480           38480
# 2013                      41101             41101           41101
# 2014                      59306             59306           59306
# 2015                      65272             65272           65272
# 2016                      49292             49292           49292
# 2017                      43419             43419           43419
#
#                launched_monthday  launched_weekday  launched_quarter  \
# launched_year
# 2009                        1179              1179              1179
# 2010                        9577              9577              9577
# 2011                       24049             24049             24049
# 2012                       38480             38480             38480
# 2013                       41101             41101             41101
# 2014                       59306             59306             59306
# 2015                       65272             65272             65272
# 2016                       49292             49292             49292
# 2017                       43419             43419             43419
#
#                weekday_count  deadline_date  launched_date
# launched_year
# 2009                    1179           1179           1179
# 2010                    9577           9577           9577
# 2011                   24049          24049          24049
# 2012                   38480          38480          38480
# 2013                   41101          41101          41101
# 2014                   59306          59306          59306
# 2015                   65272          65272          65272
# 2016                   49292          49292          49292
# 2017                   43419          43419          43419
#
# [9 rows x 27 columns]

# %%
9577/1179
# Out:
# 8.122985581000847

# %% [markdown]
# ## Data Cleaning

# %%
df3 = df.drop(['name','goal', 'pledged', 'usd pledged', 'deadline_year','deadline_month','deadline_monthday','deadline_quarter','launched_quarter','ID','deadline','launched', 'deadline_weekday','currency','category', 'launched_monthday','usd_pledged_real','backers'],axis=1)

# %%
df3 = df3[(df3['state'] == "failed") | (df3['state'] == "successful")] # Taking only successful and failed states

# %%
category = df3[['main_category','state','launched_year','launched_month','launched_weekday','country']]
numerical = df3[df3.columns.difference(['main_category','state','country','launched_year','launched_month','launched_weekday','country'])]

# %%
numerical
# Out:
#         usd_goal_real  weekday_count
# 0             1533.95             43
# 1            30000.00             42
# 2            45000.00             31
# 3             5000.00             20
# 5            50000.00             25
# ...               ...            ...
# 378654        6500.00             22
# 378657        1500.00             19
# 378658       15000.00             32
# 378659       15000.00             23
# 378660        2000.00             20
#
# [331675 rows x 2 columns]

# %%
category
# Out:
#        main_category       state  launched_year  launched_month  \
# 0         Publishing      failed           2015               8
# 1       Film & Video      failed           2017               9
# 2       Film & Video      failed           2013               1
# 3              Music      failed           2012               3
# 5               Food  successful           2016               2
# ...              ...         ...            ...             ...
# 378654          Food      failed           2017               3
# 378657  Film & Video      failed           2011               6
# 378658  Film & Video      failed           2010               7
# 378659    Technology      failed           2016               1
# 378660           Art      failed           2011               7
#
#        launched_weekday country
# 0               Tuesday      GB
# 1              Saturday      US
# 2              Saturday      US
# 3              Saturday      US
# 5                Friday      US
# ...                 ...     ...
# 378654           Monday      US
# 378657        Wednesday      US
# 378658         Thursday      US
# 378659        Wednesday      US
# 378660          Tuesday      US
#
# [331675 rows x 6 columns]

# %%
y = category['state']
category = category.drop('state', 1)

# %%
scale = preprocessing.scale(numerical)
scale = pd.DataFrame(scale,columns=numerical.columns, index = numerical.index)
scale
# Out:
#         usd_goal_real  weekday_count
# 0               -0.04           2.05
# 1               -0.01           1.94
# 2                0.00           0.73
# 3               -0.03          -0.48
# 5                0.01           0.07
# ...               ...            ...
# 378654          -0.03          -0.26
# 378657          -0.04          -0.59
# 378658          -0.02           0.84
# 378659          -0.02          -0.15
# 378660          -0.04          -0.48
#
# [331675 rows x 2 columns]

# %%
category = category.astype(object)
category = pd.get_dummies(category)

# %%
X = pd.concat([category, scale,], axis=1)

# %%
y = y.astype(object)
y = pd.get_dummies(y,drop_first=True)
y
# Out:
#         successful
# 0                0
# 1                0
# 2                0
# 3                0
# 5                1
# ...            ...
# 378654           0
# 378657           0
# 378658           0
# 378659           0
# 378660           0
#
# [331675 rows x 1 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=16)

# %% [markdown]
# ## Machine Learning Algorithm

# %%
regressors = [['LogisticRegressor',LogisticRegression()],
              ['KNeighboursClassifier',KNeighborsClassifier()],
              ['RandomForestClassifier', RandomForestClassifier()],
             ['BaggingClassifier',BaggingClassifier()],
             ['AdaboostClassifier',AdaBoostClassifier()]]
Acc = pd.DataFrame()

# %%
for mod in regressors:
    name = mod[0]
    model = mod[1]
    
    model.fit(X_train,y_train)
    actr1 = accuracy_score(y_train, model.predict(X_train))
    acte1 = accuracy_score(y_test, model.predict(X_test))
    
    Acc = Acc.append(pd.Series({'model':name, 'train_score':actr1,'test_score':acte1}),ignore_index=True )

# %%
Acc
# Out:
#                     model  train_score  test_score
# 0       LogisticRegressor         0.65        0.65
# 1   KNeighboursClassifier         0.74        0.61
# 2  RandomForestClassifier         0.97        0.63
# 3       BaggingClassifier         0.95        0.63
# 4      AdaboostClassifier         0.66        0.66

# %%
# Using cross validation to search for the best parameters
logreg = logreg = LogisticRegression()
grid_values = {'penalty': ['l1','l2'], 'C': [0.001,0.01,0.1,1,10,100,1000]}
R = GridSearchCV(logreg,grid_values, cv = 10,verbose=3,scoring='f1',n_jobs=-1)
R.fit(X_train,y_train)
R.best_estimator_

# %%
# Using cv to check the best parameters for random forest classifier
params = {
         'min_samples_split':[2,3,4,5,6,7,8,9],
         'min_samples_leaf':[1,2,3,4,5,6,7,8,9],
         'max_depth':[2,3,4,5,6,7],'n_estimators': [100,200,300,400,500]}
R = RandomizedSearchCV(RandomForestClassifier(),params,cv = 10,verbose=3,scoring='f1',n_jobs=-1)
R.fit(X_train,y_train)
R.best_estimator_

# %%
best = RandomForestClassifier(max_depth=7, min_samples_leaf=5, min_samples_split=6,n_estimators=200)
best.fit(X_train,y_train)
accuracy_score(y_test, best.predict(X_test))
# Out:
# 0.6402319528054431

# %%
best.feature_importances_
# Out:
# array([2.88983478e-03, 3.29964390e-02, 1.06129820e-02, 1.34706345e-02,
#        2.58920120e-03, 2.90350406e-02, 1.46892798e-03, 2.63419437e-02,
#        4.46287769e-03, 3.94159142e-03, 6.98589215e-02, 1.81015000e-03,
#        1.08627246e-02, 7.12341036e-02, 5.33981645e-02, 2.82301691e-04,
#        1.22323502e-03, 1.31749026e-02, 8.37003896e-03, 1.61936157e-02,
#        1.19749157e-02, 4.30344202e-02, 2.10534036e-03, 3.02605200e-03,
#        7.40890531e-04, 8.34439711e-04, 8.04820239e-04, 7.43321956e-04,
#        3.59780326e-04, 5.01108209e-04, 3.36533843e-03, 9.72842879e-04,
#        3.91210918e-04, 6.60793439e-04, 5.46131818e-04, 8.36196218e-04,
#        1.12396328e-03, 6.04660401e-04, 1.62154547e-03, 4.53280982e-04,
#        5.35443663e-04, 3.01687134e-03, 4.84803882e-04, 8.06971190e-05,
#        1.55072444e-03, 7.47004793e-05, 6.71605705e-04, 7.96062093e-05,
#        9.88715947e-04, 1.41032430e-04, 3.87093637e-04, 1.73089300e-04,
#        2.81140920e-03, 2.42833608e-04, 2.48494229e-05, 3.73709966e-03,
#        0.00000000e+00, 0.00000000e+00, 4.82239791e-04, 6.09786401e-05,
#        6.32983428e-04, 1.99592130e-05, 7.23783860e-05, 1.21444134e-04,
#        8.32645883e-05, 1.47148224e-02, 3.62158551e-01, 1.57734118e-01])

# %%
# Getting feature importances
data = list(zip(X.columns, best.feature_importances_))
new_df = pd.DataFrame(data, columns =['Feature', 'Importance'])
new_df.sort_values(ascending=False,by = 'Importance')
# Out:
#                      Feature  Importance
# 66             usd_goal_real        0.36
# 67             weekday_count        0.16
# 13  main_category_Technology        0.07
# 10       main_category_Music        0.07
# 14     main_category_Theater        0.05
# ..                       ...         ...
# 59              country_N,0"        0.00
# 54                country_IE        0.00
# 61                country_NO        0.00
# 56                country_JP        0.00
# 57                country_LU        0.00
#
# [68 rows x 2 columns]

# %%
df = df[(df['state'] == "failed") | (df['state'] == "successful")]

# %%
name = df['name']
name.dropna()
# Out:
# 0                           The Songs of Adelaide & Abullah
# 1             Greeting From Earth: ZGAC Arts Capsule For ET
# 2                                            Where is Hank?
# 3         ToshiCapital Rekordz Needs Help to Complete Album
# 5                                      Monarch Espresso Bar
#                                 ...
# 378654                Homemade fresh dog food, Cleveland OH
# 378657                                            The Tribe
# 378658    Walls of Remedy- New lesbian Romantic Comedy f...
# 378659                             BioDefense Education Kit
# 378660                    Nou Renmen Ayiti!  We Love Haiti!
# Name: name, Length: 331672, dtype: object

# %%
name.isnull().sum()
# Out:
# 3

# %%
name.describe()
# Out:
# count                       331672
# unique                      329594
# top       New EP/Music Development
# freq                            15
# Name: name, dtype: object

# %%
new = pd.DataFrame(name)
new['length'] = name.astype(str).apply(len)
new
# Out:
#                                                      name  length
# 0                         The Songs of Adelaide & Abullah      31
# 1           Greeting From Earth: ZGAC Arts Capsule For ET      45
# 2                                          Where is Hank?      14
# 3       ToshiCapital Rekordz Needs Help to Complete Album      49
# 5                                    Monarch Espresso Bar      20
# ...                                                   ...     ...
# 378654              Homemade fresh dog food, Cleveland OH      37
# 378657                                          The Tribe       9
# 378658  Walls of Remedy- New lesbian Romantic Comedy f...      71
# 378659                           BioDefense Education Kit      24
# 378660                  Nou Renmen Ayiti!  We Love Haiti!      33
#
# [331675 rows x 2 columns]

# %%
sns.histplot(x=new['length'], bins=15)
# Out:
# <AxesSubplot:xlabel='length', ylabel='Count'>

# %%
# Checking for the largest name string
new[new['length'] >= 85]['name'].iloc[14]
# Out:
# 'Be A Part of the Action! New Record Seeks Fiscal Midwives! Scandal Rocks Folk Scene! '

# %%
new['state'] = df['state']
new.hist(column='length', by = 'state', bins=30, figsize=(12,4))
# Out:
# array([<AxesSubplot:title={'center':'failed'}>,
#        <AxesSubplot:title={'center':'successful'}>], dtype=object)

# %%
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
# defining function which removes stop words and punctuations
def text_process(mess):
    
    nopunc = [x for x in mess if x not in string.punctuation]
    nopunc = ''.join(nopunc).split()
    return [word for word in nopunc if word.lower() not in stopwords.words('english')]

# %%
# changing values to unicode type  and transforming the values to count vector
new['name'] =  new['name'].values.astype('U')
bow_transformer = CountVectorizer(analyzer=text_process).fit(new['name'])

# %%
name_bow = bow_transformer.transform(new['name'])

# %%
# Printing the top 20 words which are mostly sub categories of the Projects
sum_words = name_bow.sum(axis=0) 
words_freq = [(word, sum_words[0, idx]) for word, idx in bow_transformer.vocabulary_.items()]
words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
words_freq[:20]
# Out:
# [('Project', 8700),
#  ('Album', 8516),
#  ('New', 7954),
#  ('Film', 7090),
#  ('Book', 6160),
#  ('Art', 5595),
#  ('Game', 5421),
#  ('Music', 4996),
#  ('Help', 4810),
#  ('EP', 4222),
#  ('First', 3643),
#  ('album', 3473),
#  ('new', 3406),
#  ('Short', 3358),
#  ('1', 3288),
#  ('Debut', 3251),
#  ('2', 3153),
#  ('film', 3103),
#  ('Life', 3028),
#  ('Series', 3009)]

# %%
# transforming to tfidf format
tfidf_transformer = TfidfTransformer().fit(name_bow)
name_tfidf = tfidf_transformer.transform(name_bow)

# %%
# performing logistic regrression
logreg = LogisticRegression()

# %%
X_train, X_test, y_train, y_test = train_test_split(name_tfidf, new['state'], test_size=0.2, random_state=42)

# %%
# printing the train and test accuracy scores.
logreg.fit(X_train,y_train)
print("Train Score:" , accuracy_score(y_train, logreg.predict(X_train)))
print("Test Score:" , accuracy_score(y_test, logreg.predict(X_test)))
# Out:
# Train Score: 0.7349476143815482
# Test Score: 0.6538780432652446
